# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("../vehicles_us.csv")

# %%
# Filtrar precios extremos para que los gráficos sean más claros
df_filtered = df[df["price"] < 100000]

# %%
# --- Histograma de precios por modelo (Top 10) ---
top_models = df_filtered["model"].value_counts().head(10).index
df_top = df_filtered[df_filtered["model"].isin(top_models)]

fig1 = px.histogram(df_top, x="price", color="model",
                    nbins=40, barmode="overlay",
                    title="Distribución de precios por modelo (Top 10)")
fig.show()

# %%
# --- Gráfico de dispersión (precio vs odómetro por tipo de auto) ---
fig2 = px.scatter(df_filtered, x="odometer", y="price", color="type",
                  opacity=0.5,
                  title="Precio vs Kilometraje por Tipo de Vehículo",
                  labels={"odometer": "Kilometraje", "price": "Precio"})
fig2.show()
